# %% [markdown]
# # Visualization of McStas simulated 1d pattern for BEER
#
# Instrument file is taken from http://mcstas.org/download/components/examples/ESS_BEER_MCPL.pure.html

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

# %%
file_name = 'dhkl.dat'
x, y_sim, sy_sim, n = np.loadtxt(file_name, comments='#', unpack=True)

# %%
#plt.xlim(16000.0, 17000.0)
#plt.errorbar(x, y_obs, yerr=sy_sim, fmt='o', fillstyle='none')
#plt.plot(x, y_obs, 'o', x, y_calc, '-')
plt.figure(0)
plt.plot(x, y_sim)
plt.xlabel("d-spacing (Å)")
#plt.ylabel("Intensity")
plt.title("McStas simulated pattern for BEER")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
file_name = 'dhkl.dat'
x, y_sim, sy_sim, n = np.loadtxt(file_name, comments='#', unpack=True)

# %%
x_mult = 3510
y_mult = 1e+2
y_add = 1

x = x * x_mult
y_sim = y_sim * y_mult + y_add
sy_sim = sy_sim * y_mult + y_add

header = """XYDATA McStas simulated data for BEER at ESS on duplex sample
  ...
  ...
  ...
INTER   1.0   1.0   0  0
TEMP  300.0"""
np.savetxt('duplex.dat', np.column_stack([x, y_sim, sy_sim]), fmt='%11.3f%9i%9i', header=header, comments='')

# %%
plt.figure(1)
plt.plot(x, y_sim)
plt.xlabel("d-spacing (Å)")
plt.title("McStas simulated pattern for BEER (multiplied)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
