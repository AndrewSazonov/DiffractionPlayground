# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

# %%
file_name = 'duplex.xys'
x, y_obs, sy_obs, y_calc = np.loadtxt(file_name, skiprows=6, unpack=True)#plt.xlim(16000.0, 17000.0)

#plt.xlim(3180.0, 3230.0)
#plt.figure()
plt.figure(figsize=(9, 4))
plt.plot(x, y_obs, 'o', x, y_calc, '-')
plt.xlabel("TOF")
#plt.ylabel("Intensity")
plt.title("toffit output for the McStas simulated data for BEER")
#plt.show()

plt.xlim(7000.0, 7500.0)
#plt.figure()
plt.figure(figsize=(9, 4))
plt.plot(x, y_obs, 'o', x, y_calc, '-')
plt.xlabel("TOF")
#plt.ylabel("Intensity")
plt.title("toffit output for the McStas simulated data for BEER")

plt.xlim(2800.0, 3300.0)
plt.ylim(-20.0, 120.0)
#plt.figure()
plt.figure(figsize=(9, 4))
plt.plot(x, y_obs, 'o', x, y_calc, '-')
plt.xlabel("TOF")
#plt.ylabel("Intensity")
plt.title("toffit output for the McStas simulated data for BEER")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
